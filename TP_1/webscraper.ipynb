# %%
# Import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "https://webscraper.io/test-sites/e-commerce/static"

# List to store all product data
all_products = []

print("--- Web Scraping: WebScraper.io Test E-Commerce Site ---")

try:
    # Step 1: Get all category URLs
    response = requests.get(BASE_URL)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")

    categories = soup.select("div.sidebar ul.nav > li > a")
    category_links = [
        "https://webscraper.io" + cat["href"] for cat in categories
    ]

    print(f"Found {len(category_links)} categories.")
    print("---------------------------------------")

    # Step 2: Loop through each category
    for category_url in category_links:
        print(f"Scraping category: {category_url}")
        page = 1

        while True:
            url = category_url + f"?page={page}"
            response = requests.get(url)
            if response.status_code == 404:
                break  # Stop if page doesn't exist

            soup = BeautifulSoup(response.text, "html.parser")
            products = soup.find_all("div", class_="thumbnail")

            if not products:
                break  # No more products on next page

            # Extract data for each product
            for product in products:
                if len(all_products) >= 1000: # Stop after 1000 products
                    break
                title = product.find("a", class_="title").text.strip()
                price = product.find("h4", class_="price").text.strip()
                description = product.find("p", class_="description").text.strip()

                all_products.append({
                    "Category": category_url.split("/")[-1],
                    "Title": title,
                    "Price": price,
                    "Description": description
                })

            print(f" Page {page} done ({len(all_products)} total products).")

            if len(all_products) >= 1000: # Stop after 1000 products
                break

            page += 1


        print("---------------------------------------")
        if len(all_products) >= 1000: # Stop after 1000 products
            break


    # Step 3: Save to CSV
    df = pd.DataFrame(all_products)
    df.to_csv("webscraper_1000_products.csv", index=False, encoding="utf-8")

    print(f"\n✅ Extracted {len(all_products)} products from all categories.")
    print("Data saved to 'webscraper_1000_products.csv'.")
    print("---------------------------------------")

except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# --- Web Scraping: WebScraper.io Test E-Commerce Site ---
# Found 3 categories.
# ---------------------------------------
# Scraping category: https://webscraper.io/test-sites/e-commerce/static
#  Page 1 done (3 total products).
#  Page 2 done (6 total products).
#  Page 3 done (9 total products).
#  Page 4 done (12 total products).
#  Page 5 done (15 total products).
#  Page 6 done (18 total products).
#  Page 7 done (21 total products).
#  Page 8 done (24 total products).
#  Page 9 done (27 total products).
#  Page 10 done (30 total products).
#  Page 11 done (33 total products).
#  Page 12 done (36 total products).
#  Page 13 done (39 total products).
#  Page 14 done (42 total products).
#  Page 15 done (45 total products).
#  Page 16 done (48 total products).
#  Page 17 done (51 total products).
#  Page 18 done (54 total products).
#  Page 19 done (57 total products).
#  Page 20 done (60 total products).
#  Page 21 done (63 total products).
#  Page 22 done (66 total products).
#  Page 23 done (69 total products).
#  Page 24 done (72 total products).
#  Page 25 done (75 total products).
#  Page 26 done (78 total products).
#  Page 27 done (81 total products).
#  Page 28 done (84 total products).
#  Page 29 done (87 total products).
#  Page 30 done (90 total products).
#  Page 31 done (93 total products).
#  Page 32 done (96 total products).
#  Page 33 done (99 total products).
#  Page 34 done (102 total products).
#  Page 35 done (105 total products).
#  Page 36 done (108 total products).
#  Page 37 done (111 total products).
#  Page 38 done (114 total products).
#  Page 39 done (117 total products).
#  Page 40 done (120 total products).
#  Page 41 done (123 total products).
#  Page 42 done (126 total products).
#  Page 43 done (129 total products).
#  Page 44 done (132 total products).
#  Page 45 done (135 total products).
#  Page 46 done (138 total products).
#  Page 47 done (141 total products).
#  Page 48 done (144 total products).
#  Page 49 done (147 total products).
#  Page 50 done (150 total products).
#  Page 51 done (153 total products).
#  Page 52 done (156 total products).
#  Page 53 done (159 total products).
#  Page 54 done (162 total products).
#  Page 55 done (165 total products).
#  Page 56 done (168 total products).
#  Page 57 done (171 total products).
#  Page 58 done (174 total products).
#  Page 59 done (177 total products).
#  Page 60 done (180 total products).
#  Page 61 done (183 total products).
#  Page 62 done (186 total products).
#  Page 63 done (189 total products).
#  Page 64 done (192 total products).
#  Page 65 done (195 total products).
#  Page 66 done (198 total products).
#  Page 67 done (201 total products).
#  Page 68 done (204 total products).
#  Page 69 done (207 total products).
#  Page 70 done (210 total products).
#  Page 71 done (213 total products).
#  Page 72 done (216 total products).
#  Page 73 done (219 total products).
#  Page 74 done (222 total products).
#  Page 75 done (225 total products).
#  Page 76 done (228 total products).
#  Page 77 done (231 total products).
#  Page 78 done (234 total products).
#  Page 79 done (237 total products).
#  Page 80 done (240 total products).
#  Page 81 done (243 total products).
#  Page 82 done (246 total products).
#  Page 83 done (249 total products).
#  Page 84 done (252 total products).
#  Page 85 done (255 total products).
#  Page 86 done (258 total products).
#  Page 87 done (261 total products).
#  Page 88 done (264 total products).
#  Page 89 done (267 total products).
#  Page 90 done (270 total products).
#  Page 91 done (273 total products).
#  Page 92 done (276 total products).
#  Page 93 done (279 total products).
#  Page 94 done (282 total products).
#  Page 95 done (285 total products).
#  Page 96 done (288 total products).
#  Page 97 done (291 total products).
#  Page 98 done (294 total products).
#  Page 99 done (297 total products).
#  Page 100 done (300 total products).
#  Page 101 done (303 total products).
#  Page 102 done (306 total products).
#  Page 103 done (309 total products).
#  Page 104 done (312 total products).
#  Page 105 done (315 total products).
#  Page 106 done (318 total products).
#  Page 107 done (321 total products).
#  Page 108 done (324 total products).
#  Page 109 done (327 total products).
#  Page 110 done (330 total products).
#  Page 111 done (333 total products).
#  Page 112 done (336 total products).
#  Page 113 done (339 total products).
#  Page 114 done (342 total products).
#  Page 115 done (345 total products).
#  Page 116 done (348 total products).
#  Page 117 done (351 total products).
#  Page 118 done (354 total products).
#  Page 119 done (357 total products).
#  Page 120 done (360 total products).
#  Page 121 done (363 total products).
#  Page 122 done (366 total products).
#  Page 123 done (369 total products).
#  Page 124 done (372 total products).
#  Page 125 done (375 total products).
#  Page 126 done (378 total products).
#  Page 127 done (381 total products).
#  Page 128 done (384 total products).
#  Page 129 done (387 total products).
#  Page 130 done (390 total products).
#  Page 131 done (393 total products).
#  Page 132 done (396 total products).
#  Page 133 done (399 total products).
#  Page 134 done (402 total products).
#  Page 135 done (405 total products).
#  Page 136 done (408 total products).
#  Page 137 done (411 total products).
#  Page 138 done (414 total products).
#  Page 139 done (417 total products).
#  Page 140 done (420 total products).
#  Page 141 done (423 total products).
#  Page 142 done (426 total products).
#  Page 143 done (429 total products).
#  Page 144 done (432 total products).
#  Page 145 done (435 total products).
#  Page 146 done (438 total products).
#  Page 147 done (441 total products).
#  Page 148 done (444 total products).
#  Page 149 done (447 total products).
#  Page 150 done (450 total products).
#  Page 151 done (453 total products).
#  Page 152 done (456 total products).
#  Page 153 done (459 total products).
#  Page 154 done (462 total products).
#  Page 155 done (465 total products).
#  Page 156 done (468 total products).
#  Page 157 done (471 total products).
#  Page 158 done (474 total products).
#  Page 159 done (477 total products).
#  Page 160 done (480 total products).
#  Page 161 done (483 total products).
#  Page 162 done (486 total products).
#  Page 163 done (489 total products).
#  Page 164 done (492 total products).
#  Page 165 done (495 total products).
#  Page 166 done (498 total products).
#  Page 167 done (501 total products).
#  Page 168 done (504 total products).
#  Page 169 done (507 total products).
#  Page 170 done (510 total products).
#  Page 171 done (513 total products).
#  Page 172 done (516 total products).
#  Page 173 done (519 total products).
#  Page 174 done (522 total products).
#  Page 175 done (525 total products).
#  Page 176 done (528 total products).
#  Page 177 done (531 total products).
#  Page 178 done (534 total products).
#  Page 179 done (537 total products).
#  Page 180 done (540 total products).
#  Page 181 done (543 total products).
#  Page 182 done (546 total products).
#  Page 183 done (549 total products).
#  Page 184 done (552 total products).
#  Page 185 done (555 total products).
#  Page 186 done (558 total products).
#  Page 187 done (561 total products).
#  Page 188 done (564 total products).
#  Page 189 done (567 total products).
#  Page 190 done (570 total products).
#  Page 191 done (573 total products).
#  Page 192 done (576 total products).
#  Page 193 done (579 total products).
#  Page 194 done (582 total products).
#  Page 195 done (585 total products).
#  Page 196 done (588 total products).
#  Page 197 done (591 total products).
#  Page 198 done (594 total products).
#  Page 199 done (597 total products).
#  Page 200 done (600 total products).
#  Page 201 done (603 total products).
#  Page 202 done (606 total products).
#  Page 203 done (609 total products).
#  Page 204 done (612 total products).
#  Page 205 done (615 total products).
#  Page 206 done (618 total products).
#  Page 207 done (621 total products).
#  Page 208 done (624 total products).
#  Page 209 done (627 total products).
#  Page 210 done (630 total products).
#  Page 211 done (633 total products).
#  Page 212 done (636 total products).
#  Page 213 done (639 total products).
#  Page 214 done (642 total products).
#  Page 215 done (645 total products).
#  Page 216 done (648 total products).
#  Page 217 done (651 total products).
#  Page 218 done (654 total products).
#  Page 219 done (657 total products).
#  Page 220 done (660 total products).
#  Page 221 done (663 total products).
#  Page 222 done (666 total products).
#  Page 223 done (669 total products).
#  Page 224 done (672 total products).
#  Page 225 done (675 total products).
#  Page 226 done (678 total products).
#  Page 227 done (681 total products).
#  Page 228 done (684 total products).
#  Page 229 done (687 total products).
#  Page 230 done (690 total products).
#  Page 231 done (693 total products).
#  Page 232 done (696 total products).
#  Page 233 done (699 total products).
#  Page 234 done (702 total products).
#  Page 235 done (705 total products).
#  Page 236 done (708 total products).
#  Page 237 done (711 total products).
#  Page 238 done (714 total products).
#  Page 239 done (717 total products).
#  Page 240 done (720 total products).
#  Page 241 done (723 total products).
#  Page 242 done (726 total products).
#  Page 243 done (729 total products).
#  Page 244 done (732 total products).
#  Page 245 done (735 total products).
#  Page 246 done (738 total products).
#  Page 247 done (741 total products).
#  Page 248 done (744 total products).
#  Page 249 done (747 total products).
#  Page 250 done (750 total products).
#  Page 251 done (753 total products).
#  Page 252 done (756 total products).
#  Page 253 done (759 total products).
#  Page 254 done (762 total products).
#  Page 255 done (765 total products).
#  Page 256 done (768 total products).
#  Page 257 done (771 total products).
#  Page 258 done (774 total products).
#  Page 259 done (777 total products).
#  Page 260 done (780 total products).
#  Page 261 done (783 total products).
#  Page 262 done (786 total products).
#  Page 263 done (789 total products).
#  Page 264 done (792 total products).
#  Page 265 done (795 total products).
#  Page 266 done (798 total products).
#  Page 267 done (801 total products).
#  Page 268 done (804 total products).
#  Page 269 done (807 total products).
#  Page 270 done (810 total products).
#  Page 271 done (813 total products).
#  Page 272 done (816 total products).
#  Page 273 done (819 total products).
#  Page 274 done (822 total products).
#  Page 275 done (825 total products).
#  Page 276 done (828 total products).
#  Page 277 done (831 total products).
#  Page 278 done (834 total products).
#  Page 279 done (837 total products).
#  Page 280 done (840 total products).
#  Page 281 done (843 total products).
#  Page 282 done (846 total products).
#  Page 283 done (849 total products).
#  Page 284 done (852 total products).
#  Page 285 done (855 total products).
#  Page 286 done (858 total products).
#  Page 287 done (861 total products).
#  Page 288 done (864 total products).
#  Page 289 done (867 total products).
#  Page 290 done (870 total products).
#  Page 291 done (873 total products).
#  Page 292 done (876 total products).
#  Page 293 done (879 total products).
#  Page 294 done (882 total products).
#  Page 295 done (885 total products).
#  Page 296 done (888 total products).
#  Page 297 done (891 total products).
#  Page 298 done (894 total products).
#  Page 299 done (897 total products).
#  Page 300 done (900 total products).
#  Page 301 done (903 total products).
#  Page 302 done (906 total products).
#  Page 303 done (909 total products).
#  Page 304 done (912 total products).
#  Page 305 done (915 total products).
#  Page 306 done (918 total products).
#  Page 307 done (921 total products).
#  Page 308 done (924 total products).
#  Page 309 done (927 total products).
#  Page 310 done (930 total products).
#  Page 311 done (933 total products).
#  Page 312 done (936 total products).
#  Page 313 done (939 total products).
#  Page 314 done (942 total products).
#  Page 315 done (945 total products).
#  Page 316 done (948 total products).
#  Page 317 done (951 total products).
#  Page 318 done (954 total products).
#  Page 319 done (957 total products).
#  Page 320 done (960 total products).
#  Page 321 done (963 total products).
#  Page 322 done (966 total products).
#  Page 323 done (969 total products).
#  Page 324 done (972 total products).
#  Page 325 done (975 total products).
#  Page 326 done (978 total products).
#  Page 327 done (981 total products).
#  Page 328 done (984 total products).
#  Page 329 done (987 total products).
#  Page 330 done (990 total products).
#  Page 331 done (993 total products).
#  Page 332 done (996 total products).
#  Page 333 done (999 total products).
#  Page 334 done (1000 total products).
# ---------------------------------------
#
# ✅ Extracted 1000 products from all categories.
# Data saved to 'webscraper_1000_products.csv'.
# ---------------------------------------
